# %%
from langgraph.prebuilt import create_react_agent
from langchain_openai import ChatOpenAI
from IPython.display import Image, display
import os
from dotenv import load_dotenv

load_dotenv()

# Create the 'create_agent' helper with the correct parameter name
def create_agent(model, tools, system_prompt):
    llm = ChatOpenAI(model=model)
    # Changed 'state_modifier' to 'prompt' to fix your TypeError
    agent = create_react_agent(llm, tools=tools, prompt=system_prompt)
    
    # Try to display the graph image
    try:
        display(Image(agent.get_graph().draw_mermaid_png()))
    except Exception as e:
        print(f"Could not display graph image: {e}")
        
    return agent
# Out:
# /Users/mc/Documents/PythonProjects/LangChainUpdated/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/mc/Documents/PythonProjects/LangChainUpdated/.venv/lib/python3.9/site-packages/langgraph/checkpoint/base/__init__.py:18: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit value (e.g., allowed_objects='messages' or allowed_objects='core') to suppress this warning.
#   from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer

# %%
agent = create_agent(
    model="gpt-4o",
    tools=[],
    system_prompt="You are a helpful assistant."
)
agent

# %% [markdown]
# ### Langchain Version v1
